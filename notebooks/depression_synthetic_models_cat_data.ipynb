# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_theme()
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder

from sklearn import metrics
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve
)
from sklearn.model_selection import (
    KFold,
    RandomizedSearchCV,
    StratifiedKFold,
    cross_val_score,
    train_test_split,
)
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

import shap
from lime.lime_tabular import LimeTabularExplainer

import logging
from IPython import display

logging.getLogger("kedro.ipython").disabled = True

logging.getLogger("kedro.io.data_catalog").disabled = True

# %load_ext kedro.ipython
warnings.filterwarnings('ignore')
display.clear_output()
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Dataset Loading

# %%
df = catalog.load('depression_synthetic_cleaned')
df_real = catalog.load('depression_real_cleaned')
df.info()
# Out:
# [11/29/24 04:20:35] INFO     Loading data from depression_synthetic_cleaned (CSVDataset)...     ]8;id=902398;file://C:\Users\divya\miniconda3\envs\mlops\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=361470;file://C:\Users\divya\miniconda3\envs\mlops\lib\site-packages\kedro\io\data_catalog.py#539\539]8;;\
#                     INFO     Loading data from depression_real_cleaned (CSVDataset)...          ]8;id=285389;file://C:\Users\divya\miniconda3\envs\mlops\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=16876;file://C:\Users\divya\miniconda3\envs\mlops\lib\site-packages\kedro\io\data_catalog.py#539\539]8;;\
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140602 entries, 0 to 140601
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Name                                   140602 non-null  object
#  1   Gender                                 140602 non-null  object
#  2   Age                                    140602 non-null  float64
#  3   City                                   140602 non-null  object
#  4   Working Professional or Student        140602 non-null  object
#  5   Profession                             140602 non-null  object
#  6   Academic Pressure                      140602 non-null  float64
#  7   Work Pressure                          140602 non-null  float64
#  8   CGPA                                   140602 non-null  float64
#  9   Study Satisfaction                     140602 non-null  float64
#  10  Job Satisfaction                       140602 non-null  float64
#  11  Sleep Duration                         140602 non-null  object
#  12  Dietary Habits                         140602 non-null  object
#  13  Degree                                 140602 non-null  object
#  14  Have you ever had suicidal thoughts ?  140602 non-null  object
#  15  Work/Study Hours                       140602 non-null  float64
#  16  Financial Stress                       140602 non-null  float64
#  17  Family History of Mental Illness       140602 non-null  object
#  18  Depression                             140602 non-null  int64
# dtypes: float64(8), int64(1), object(10)
# memory usage: 20.4+ MB

# %%
print(df.isnull().sum())
print("-"*50)
print(df_real.isnull().sum())
# Out:
# Name                                     0
# Gender                                   0
# Age                                      0
# City                                     0
# Working Professional or Student          0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64
# --------------------------------------------------
# Name                                     0
# Gender                                   0
# Age                                      0
# City                                     0
# Working Professional or Student          0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
print(df.nunique().sort_values())
print("-"*50)
print(df.nunique().sort_values())
# Out:
# Gender                                     2
# Working Professional or Student            2
# Have you ever had suicidal thoughts ?      2
# Family History of Mental Illness           2
# Depression                                 2
# Dietary Habits                             3
# Sleep Duration                             5
# Study Satisfaction                         6
# Job Satisfaction                           6
# Financial Stress                           6
# Academic Pressure                          6
# Work Pressure                              6
# Work/Study Hours                          13
# Degree                                    28
# City                                      30
# Profession                                35
# Age                                       43
# CGPA                                     332
# Name                                     422
# dtype: int64
# --------------------------------------------------
# Gender                                     2
# Working Professional or Student            2
# Have you ever had suicidal thoughts ?      2
# Family History of Mental Illness           2
# Depression                                 2
# Dietary Habits                             3
# Sleep Duration                             5
# Study Satisfaction                         6
# Job Satisfaction                           6
# Financial Stress                           6
# Academic Pressure                          6
# Work Pressure                              6
# Work/Study Hours                          13
# Degree                                    28
# City                                      30
# Profession                                35
# Age                                       43
# CGPA                                     332
# Name                                     422
# dtype: int64

# %%
df.describe(include="object")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           Name  Gender    City Working Professional or Student Profession  \
# count   140602  140602  140602                          140602     140602
# unique     422       2      30                               2         35
# top      Rohan    Male  Kalyan            Working Professional      Other
# freq      3178   77412    6591                          112727      61548
#
#            Sleep Duration Dietary Habits    Degree  \
# count              140602         140602    140602
# unique                  5              3        28
# top     Less than 5 hours       Moderate  Class 12
# freq                38761          49695     14722
#
#        Have you ever had suicidal thoughts ? Family History of Mental Illness
# count                                 140602                           140602
# unique                                     2                                2
# top                                       No                               No
# freq                                   71092                            70705

# %% [markdown]
# # Models

# %% [markdown]
# ## Train with Categorical data only

# %%
object_cols = [col for col in df.columns if df[col].dtype == "object"]
object_cols
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'Name',
#     'Gender',
#     'City',
#     'Working Professional or Student',
#     'Profession',
#     'Sleep Duration',
#     'Dietary Habits',
#     'Degree',
#     'Have you ever had suicidal thoughts ?',
#     'Family History of Mental Illness'
# ]

# %% [markdown]
# ## Label Encoding

# %%
le = LabelEncoder()
# Apply LabelEncoder to each categorical column and replace it in the DataFrame
for col in object_cols:
    df[col] = le.fit_transform(df[col])
    df_real[col] = le.fit_transform(df_real[col])

# %% [markdown]
# ## Split data

# %%
df_X = df[object_cols]
df_y = df['Depression']
print(df_X.columns)
print("-"*50)
df_real_X = df_real[object_cols]
df_real_y = df_real['Depression']
print(df_real_X.columns)
# Out:
# Index(['Name', 'Gender', 'City', 'Working Professional or Student',
#        'Profession', 'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?',
#        'Family History of Mental Illness'],
#       dtype='object')
# --------------------------------------------------
# Index(['Name', 'Gender', 'City', 'Working Professional or Student',
#        'Profession', 'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?',
#        'Family History of Mental Illness'],
#       dtype='object')

# %%
df_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140602 entries, 0 to 140601
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Name                                   140602 non-null  int64
#  1   Gender                                 140602 non-null  int64
#  2   City                                   140602 non-null  int64
#  3   Working Professional or Student        140602 non-null  int64
#  4   Profession                             140602 non-null  int64
#  5   Sleep Duration                         140602 non-null  int64
#  6   Dietary Habits                         140602 non-null  int64
#  7   Degree                                 140602 non-null  int64
#  8   Have you ever had suicidal thoughts ?  140602 non-null  int64
#  9   Family History of Mental Illness       140602 non-null  int64
# dtypes: int64(10)
# memory usage: 10.7 MB

# %%
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, shuffle=True, test_size=0.3, random_state=42)

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### Train

# %%
# Train
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)

# Predict on val
y_preds = clf.predict(X_test)
print('Accuracy of logistic regression classifier on validation set: {:.2f}'.format(clf.score(X_test, y_test)))

# Evaluate the model on test set
accuracy = accuracy_score(y_test, y_preds)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_preds))

print("-"*75)

# Predict on real world data
y_preds_real = clf.predict(df_real_X)
print('Accuracy of logistic regression classifier on real world dataset: {:.2f}'.format(clf.score(df_real_X, df_real_y)))

# Evaluate the model on real world data
accuracy = accuracy_score(df_real_y, y_preds_real)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(df_real_y, y_preds_real))
# Out:
# Accuracy of logistic regression classifier on validation set: 0.89
# Accuracy: 0.89
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93     34505
#            1       0.79      0.54      0.64      7676
#
#     accuracy                           0.89     42181
#    macro avg       0.85      0.75      0.79     42181
# weighted avg       0.88      0.89      0.88     42181
#
# ---------------------------------------------------------------------------
# Accuracy of logistic regression classifier on real world dataset: 0.87
# Accuracy: 0.87
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      2101
#            1       0.73      0.42      0.53       455
#
#     accuracy                           0.87      2556
#    macro avg       0.81      0.69      0.73      2556
# weighted avg       0.86      0.87      0.85      2556

# %% [markdown]
# ### Coefficients

# %%
pd.DataFrame({'coeff': clf.coef_[0]}, 
             index=df_X.columns)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                           coeff
# Name                                  -0.000085
# Gender                                 0.023540
# City                                  -0.008485
# Working Professional or Student       -2.825306
# Profession                             0.028934
# Sleep Duration                        -0.005222
# Dietary Habits                         0.527297
# Degree                                -0.011112
# Have you ever had suicidal thoughts ?  2.417601
# Family History of Mental Illness       0.150467

# %%
pd.DataFrame({'coeff': clf.coef_[0]}, 
             index=df_X.columns).plot(kind = "bar")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %% [markdown]
# ### Confusion Matrix on val data

# %%
# Comfusion Matrix on val data
cm_np = confusion_matrix(y_test.tolist(), y_preds.tolist())
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm_np, display_labels = [0, 1])
cm_display.plot()
plt.show()

# ROC Curve
logit_roc_auc = roc_auc_score(y_test, clf.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, clf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'y-.')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %% [markdown]
# ### Confusion Matrix and ROC-AUC curve on real world data

# %%
# Comfusion Matrix on val data
cm_np = confusion_matrix(df_real_y.tolist(), y_preds_real.tolist())
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm_np, display_labels = [0, 1])
cm_display.plot()
plt.show()

# ROC Curve
logit_roc_auc = roc_auc_score(df_real_y, clf.predict(df_real_X))
fpr, tpr, thresholds = roc_curve(df_real_y, clf.predict_proba(df_real_X)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'y-.')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %% [markdown]
# ## Random Forest

# %%
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

# Predict on val
y_preds = clf.predict(X_test)
print('Accuracy of RF classifier on validation set: {:.2f}'.format(clf.score(X_test, y_test)))

# Evaluate the model on test set
accuracy = accuracy_score(y_test, y_preds)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_preds))

print("-"*75)

# Predict on real world data
y_preds_real = clf.predict(df_real_X)
print('Accuracy of RF classifier on real world dataset: {:.2f}'.format(clf.score(df_real_X, df_real_y)))

# Evaluate the model on real world data
accuracy = accuracy_score(df_real_y, y_preds_real)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(df_real_y, y_preds_real))
# Out:
# Accuracy of RF classifier on validation set: 0.89
# Accuracy: 0.89
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93     34505
#            1       0.73      0.61      0.66      7676
#
#     accuracy                           0.89     42181
#    macro avg       0.82      0.78      0.80     42181
# weighted avg       0.88      0.89      0.88     42181
#
# ---------------------------------------------------------------------------
# Accuracy of RF classifier on real world dataset: 0.87
# Accuracy: 0.87
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92      2101
#            1       0.66      0.49      0.56       455
#
#     accuracy                           0.87      2556
#    macro avg       0.78      0.72      0.74      2556
# weighted avg       0.85      0.87      0.86      2556

# %%
pd.DataFrame({'coeff': clf.feature_importances_}, 
             index=df_X.columns)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                           coeff
# Name                                   0.196831
# Gender                                 0.016157
# City                                   0.146171
# Working Professional or Student        0.226389
# Profession                             0.080131
# Sleep Duration                         0.040116
# Dietary Habits                         0.028893
# Degree                                 0.122600
# Have you ever had suicidal thoughts ?  0.124458
# Family History of Mental Illness       0.018255

# %%
pd.DataFrame({'coeff': clf.feature_importances_}, 
             index=df_X.columns).plot(kind = "bar")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Axes: >
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %%
# Comfusion Matrix on val data
cm_np = confusion_matrix(y_test.tolist(), y_preds.tolist())
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm_np, display_labels = [0, 1])
cm_display.plot()
plt.show()

# ROC Curve
logit_roc_auc = roc_auc_score(y_test, clf.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, clf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Random Forest (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'y-.')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %% [markdown]
# ## Decision Tree

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train, y_train)

# Predict on val
y_preds = clf.predict(X_test)
print('Accuracy of DT classifier on validation set: {:.2f}'.format(clf.score(X_test, y_test)))

# Evaluate the model on test set
accuracy = accuracy_score(y_test, y_preds)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_preds))

print("-"*75)

# Predict on real world data
y_preds_real = clf.predict(df_real_X)
print('Accuracy of DT classifier on real world dataset: {:.2f}'.format(clf.score(df_real_X, df_real_y)))

# Evaluate the model on real world data
accuracy = accuracy_score(df_real_y, y_preds_real)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(df_real_y, y_preds_real))
# Out:
# Accuracy of DT classifier on validation set: 0.90
# Accuracy: 0.90
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94     34505
#            1       0.76      0.64      0.69      7676
#
#     accuracy                           0.90     42181
#    macro avg       0.84      0.80      0.81     42181
# weighted avg       0.89      0.90      0.89     42181
#
# ---------------------------------------------------------------------------
# Accuracy of DT classifier on real world dataset: 0.87
# Accuracy: 0.87
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92      2101
#            1       0.68      0.51      0.58       455
#
#     accuracy                           0.87      2556
#    macro avg       0.79      0.73      0.75      2556
# weighted avg       0.86      0.87      0.86      2556

# %%
def explain_dt_output(clf, data, sample_id_in_data):
    node_indicator = clf.decision_path(data)
    leaf_id = clf.apply(data)
    
    sample_id = sample_id_in_data

    node_index = node_indicator.indices[
        node_indicator.indptr[sample_id] : node_indicator.indptr[sample_id + 1]
    ]
    print("\nVisited Node Indices:", node_index)
    
    feature = clf.tree_.feature
    threshold = clf.tree_.threshold
    values = clf.tree_.value
    
    print("Leaf ID: ", leaf_id[sample_id])
    print("Rules used to predict sample {id}:\n".format(id=sample_id))
    
    for node_id in node_index:
    
        # continue if leaf
        if leaf_id[sample_id] == node_id:
            continue
    
        # check if value of the split feature for sample 0 is below threshold
        if data.iloc[sample_id, feature[node_id]] <= threshold[node_id]:
            threshold_sign = "<="
        else:
            threshold_sign = ">"
    
        print(
                f"decision node {node_id} : ({data.columns[feature[node_id]]} = {data.iloc[sample_id, feature[node_id]]}) "
                f"{threshold_sign} {threshold[node_id]})"
            )

# %%
explain_dt_output(clf, df_real_X, 0)
# Out:
# Visited Node Indices: [  0 250 251 252 284 285 293 297 298]
# Leaf ID:  298
# Rules used to predict sample 0:
#
# decision node 0 : (Working Professional or Student = 1) > 0.5)
# decision node 250 : (Have you ever had suicidal thoughts ? = 0) <= 0.5)
# decision node 251 : (Dietary Habits = 1) <= 1.5)
# decision node 252 : (Degree = 18) > 14.5)
# decision node 284 : (Name = 128) <= 405.5)
# decision node 285 : (Name = 128) > 36.5)
# decision node 293 : (Degree = 18) > 16.5)
# decision node 297 : (City = 7) <= 21.5)

# %% [markdown]
# ## XGBoost

# %%
# Initialize
# clf = XGBClassifier(
#     objective='multi:softmax',  # For multiclass classification
#     num_class=2,               # Number of classes
#     max_depth=4,               # Maximum depth of a tree
#     learning_rate=0.1,         # Step size shrinkage
#     n_estimators=100,          # Number of boosting rounds
#     random_state=42
# )

clf = XGBClassifier(random_state=42)

# Train
clf.fit(X_train, y_train)

# Make predictions on test set
y_preds = clf.predict(X_test)
print('Accuracy of XGB classifier on validation set: {:.2f}'.format(clf.score(X_test, y_test)))

# Evaluate the model on test set
accuracy = accuracy_score(y_test, y_preds)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_preds))

print("-"*75)

# Predict on real world data
y_preds_real = clf.predict(df_real_X)
print('Accuracy of DT classifier on real world dataset: {:.2f}'.format(clf.score(df_real_X, df_real_y)))

# Evaluate the model on real world data
accuracy = accuracy_score(df_real_y, y_preds_real)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(df_real_y, y_preds_real))
# Out:
# Accuracy of XGB classifier on validation set: 0.90
# Accuracy: 0.90
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94     34505
#            1       0.76      0.64      0.69      7676
#
#     accuracy                           0.90     42181
#    macro avg       0.84      0.80      0.82     42181
# weighted avg       0.89      0.90      0.89     42181
#
# ---------------------------------------------------------------------------
# Accuracy of DT classifier on real world dataset: 0.86
# Accuracy: 0.86
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      2101
#            1       0.67      0.45      0.54       455
#
#     accuracy                           0.86      2556
#    macro avg       0.78      0.70      0.73      2556
# weighted avg       0.85      0.86      0.85      2556

# %%
def explain_single_instance(clf, instance, features):
    shap.initjs()
    explainer = shap.TreeExplainer(clf)
    shap_values = explainer.shap_values(instance)
    shap.plots.force(explainer.expected_value, shap_values[0], features)

# %%
explain_single_instance(clf, df_real_X.head(1), X_train.columns)
# Out:
# here
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>

# %%
shap.initjs()
explainer = shap.TreeExplainer(clf)
shap_values = explainer(X_train)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>

# %%
shap.plots.violin(shap_values, plot_type="layered_violin", show = False)
fig, ax = plt.gcf(), plt.gca()
fig.set_figheight(7)
fig.set_figwidth(7)
ax.tick_params(labelsize=8)
ax.set_title("SHAP Summary | layered_violin", fontsize=12)
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 700x700 with 2 Axes>

# %%
shap.plots.force(shap_values[0])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <shap.plots._force.AdditiveForceVisualizer object at 0x000001A9862764D0>

# %%
shap.plots.waterfall(shap_values[0], max_display=23, show= True)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 800x650 with 3 Axes>

# %%
# shap.plots.heatmap(shap_values, max_display = 23, show = False)
# fig, ax = plt.gcf(), plt.gca()
# fig.set_figheight(5)
# fig.set_figwidth(10)
# ax.tick_params(labelsize=8)
# cb_ax = fig.axes[1] 
# cb_ax.tick_params(labelsize=8)
# cb_ax.set_ylabel("Shap value", fontsize=8)
# ax.set_title("Shap plots HeatMap", fontsize=12)
# plt.show()
